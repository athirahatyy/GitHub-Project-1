# %%
import pandas as pd
import numpy as np
import tensorflow as tf

# allow memory
physical_devices = tf.config.list_physical_devices('GPU') 
tf.config.experimental.set_memory_growth(physical_devices[0], True)

heart = pd.read_csv('./heart.csv')
heart.describe()
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# min       0.000000     0.000000    71.000000     0.000000     0.000000
# 25%       0.000000     0.000000   132.000000     0.000000     0.000000
# 50%       0.000000     1.000000   152.000000     0.000000     0.800000
# 75%       0.000000     1.000000   166.000000     1.000000     1.800000
# max       1.000000     2.000000   202.000000     1.000000     6.200000
#
#              slope           ca         thal       target
# count  1025.000000  1025.000000  1025.000000  1025.000000
# mean      1.385366     0.754146     2.323902     0.513171
# std       0.617755     1.030798     0.620660     0.500070
# min       0.000000     0.000000     0.000000     0.000000
# 25%       1.000000     0.000000     2.000000     0.000000
# 50%       1.000000     0.000000     2.000000     1.000000
# 75%       2.000000     1.000000     3.000000     1.000000
# max       2.000000     4.000000     3.000000     1.000000

# %%
labels= np.array(heart.iloc[:,-1:])
features= np.array(heart.iloc[:,:13])
print(labels.shape)
print(features.shape)
# Out:
# (1025, 1)
# (1025, 13)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.3, random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
# define min max scaler
scaler = StandardScaler()
# transform data
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.fit_transform(X_test)
print(X_train_scaled.shape)
# Out:
# (717, 13)

# %%
# model neural network
network = tf.keras.models.Sequential()
network.add(tf.keras.layers.Dense(512, activation='relu', input_shape=(13,)))
network.add(tf.keras.layers.Dense(128, activation='relu'))
network.add(tf.keras.layers.Dense(2, activation='softmax'))

network.compile(optimizer='rmsprop', loss='categorical_crossentropy',metrics=['accuracy'])

# Create training and test split
#X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, stratify=y, random_state=42)

# Create categorical labels
train_labels = tf.keras.utils.to_categorical(y_train)
test_labels = tf.keras.utils.to_categorical(y_test)

# Fit the neural network
network.fit(X_train_scaled,train_labels, epochs=20, batch_size=40)

test_loss, test_acc = network.evaluate(X_test_scaled, test_labels)

print('Test Accuracy: ', test_acc, '\nTest Loss: ', test_loss)

#untuk train xbuat lg
# Out:
# Epoch 1/20
# 18/18 [==============================] - 0s 1ms/step - loss: 0.4043 - accuracy: 0.8243
# Epoch 2/20
# 18/18 [==============================] - 0s 2ms/step - loss: 0.3167 - accuracy: 0.8550
# Epoch 3/20
# 18/18 [==============================] - 0s 1ms/step - loss: 0.2688 - accuracy: 0.8982
# Epoch 4/20
# 18/18 [==============================] - 0s 1ms/step - loss: 0.2303 - accuracy: 0.9066
# Epoch 5/20
# 18/18 [==============================] - 0s 2ms/step - loss: 0.2010 - accuracy: 0.9233
# Epoch 6/20
# 18/18 [==============================] - 0s 2ms/step - loss: 0.1689 - accuracy: 0.9484
# Epoch 7/20
# 18/18 [==============================] - 0s 1ms/step - loss: 0.1415 - accuracy: 0.9596
# Epoch 8/20
# 18/18 [==============================] - 0s 1ms/step - loss: 0.1163 - accuracy: 0.9679
# Epoch 9/20
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0968 - accuracy: 0.9763
# Epoch 10/20
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0827 - accuracy: 0.9763
# Epoch 11/20
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0666 - accuracy: 0.9819
# Epoch 12/20
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0542 - accuracy: 0.9902
# Epoch 13/20
# 18/18 [==============================] - 0s 2ms/step - loss: 0.0509 - accuracy: 0.9916
# Epoch 14/20
# 18/18 [==============================] - 0s 1ms/step - loss: 0.0290 - accuracy: 0.9986
# Epoch 15/20
# 18/18 [==============================] - 0s 1ms/step - loss: 0.0301 - accuracy: 0.9944
# Epoch 16/20
# 18/18 [==============================] - 0s 1ms/step - loss: 0.0203 - accuracy: 1.0000
# Epoch 17/20
# 18/18 [==============================] - 0s 1ms/step - loss: 0.0160 - accuracy: 1.0000
# Epoch 18/20
# 18/18 [==============================] - 0s 1ms/step - loss: 0.0137 - accuracy: 0.9986
# Epoch 19/20
# 18/18 [==============================] - 0s 1ms/step - loss: 0.0124 - accuracy: 0.9986
# Epoch 20/20
# 18/18 [==============================] - 0s 1ms/step - loss: 0.0066 - accuracy: 1.0000
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0051 - accuracy: 1.0000
# Test Accuracy:  1.0
# Test Loss:  0.005076684523373842
